# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Alphabets_data.csv')
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
df.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
df.nunique()
# Out:
# letter    26
# xbox      16
# ybox      16
# width     16
# height    16
# onpix     16
# xbar      16
# ybar      16
# x2bar     16
# y2bar     16
# xybar     16
# x2ybar    16
# xy2bar    16
# xedge     16
# xedgey    16
# yedge     16
# yedgex    16
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=['letter'])
y=df['letter']

# %%
x
# Out:
#        xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0         2     8      3       5      1     8    13      0      6      6
# 1         5    12      3       7      2    10     5      5      4     13
# 2         4    11      6       8      6    10     6      2      6     10
# 3         7    11      6       6      3     5     9      4      6      4
# 4         2     1      3       1      1     8     6      6      6      6
# ...     ...   ...    ...     ...    ...   ...   ...    ...    ...    ...
# 19995     2     2      3       3      2     7     7      7      6      6
# 19996     7    10      8       8      4     4     8      6      9     12
# 19997     6     9      6       7      5     6    11      3      7     11
# 19998     2     3      4       2      1     8     7      2      6     10
# 19999     4     9      6       6      2     9     5      3      1      8
#
#        x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# ...

# %%
y
# Out:
# 0        T
# 1        I
# 2        D
# 3        N
# 4        G
#         ..
# 19995    D
# 19996    C
# 19997    T
# 19998    S
# 19999    A
# Name: letter, Length: 20000, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# !pip install keras

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(64,activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(26, activation='softmax') 
])
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np

# create a labelEncoder object
le= LabelEncoder()

# fit the labelencoder on the unique labels in y_train
le.fit(np.unique(y_train))

# transform the string labels in y_train to numerical labels
y_train= le.transform(y_train)

# %%
# extract the feature and label from the dataframe 
x= df.drop('letter',axis=1)
y=df['letter']

# %%
history= model.fit(X_train,y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.2542 - loss: 2.9250 - val_accuracy: 0.6434 - val_loss: 1.3416
# Epoch 2/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6608 - loss: 1.1926 - val_accuracy: 0.7075 - val_loss: 1.0361
# Epoch 3/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7315 - loss: 0.9489 - val_accuracy: 0.7494 - val_loss: 0.9061
# Epoch 4/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7597 - loss: 0.8312 - val_accuracy: 0.7791 - val_loss: 0.7882
# Epoch 5/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7819 - loss: 0.7433 - val_accuracy: 0.7906 - val_loss: 0.7444
# Epoch 6/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8023 - loss: 0.6710 - val_accuracy: 0.8062 - val_loss: 0.6640
# Epoch 7/10
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8237 - loss: 0.6144 - val_accuracy: 0.8209 - val_loss: 0.6266
# Epoch 8/10
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# create a LabelEncoder object
le= LabelEncoder()

# fit the LabelEncoder on the unique labels in y_test
le.fit(np.unique(y_test))

# transform the string labels in y_test to numerical labels 
y_test= le.transform(y_test)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#y_test = y_test.astype("category")

# %%
X_test= X_test.astype(np.float32)
y_test= y_test.astype(np.int32)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8514 - loss: 0.5035

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import StratifiedKFold

# %%
def create_model(optimizer='adam',activation='relu'):
    model = Sequential([
        Dense(64,activation=activation,input_shape=(X_train.shape[1],)),
        Dense(64,activation=activation),
        Dense(64,activation='softmax')
    ])

# %%
optimizer = 'adam'

# %%
model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
def forward(self, x):
    return self.model(x)

# %%
model = create_model()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
scoring = {'accuracy': make_scorer(accuracy_score)}

# %%
param_grid = {
    'optimizer':['adam','rmsprop'],
    'activation': ['relu','tanh','sigmoid']}

# %%
cv = StratifiedKFold(n_splits=3, shuffle=True,random_state=42)

# %%
grid_search= GridSearchCV(estimator=model, param_grid=param_grid, cv=cv, scoring=scoring, refit='accuracy')

# %%
grid_search
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=None,
#              param_grid={'activation': ['relu', 'tanh', 'sigmoid'],
#                          'optimizer': ['adam', 'rmsprop']},
#              refit='accuracy',
#              scoring={'accuracy': make_scorer(accuracy_score)})
