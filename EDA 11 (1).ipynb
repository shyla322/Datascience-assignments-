# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Cardiotocographic.csv',index_col=0)
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
# first 5 rows
df.head()
# Out:
#                   AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# LB
# 120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#             MLTV  Width  Tendency  NSP
# LB
# 120.000000   2.4   64.0  0.999926  2.0
# 132.000000  10.4  130.0  0.000000  1.0
# 133.000000  13.4  130.0  0.000000  1.0
# 134.000000  23.0  117.0  1.000000  1.0
# 131.948232  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 13)

# %%
df.columns
# Out:
# Index(['AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV',
#        'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
#checking null values
df.isnull().sum()
# Out:
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# # filling null values

# %%
df['AC'].mean()
# Out:
# 0.0032189782438000465

# %%
df['AC']=df['AC'].fillna(df['AC'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['DS'].mean()
# Out:
# 2.5089835057102827e-06

# %%
df['DS']=df['DS'].fillna(df['DS'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['DP'].mean()
# Out:
# 0.00017515121174634704

# %%
df['DP']=df['DP'].fillna(df['DP'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['MLTV'].mean()
# Out:
# 8.28488742706321

# %%
df['MLTV']=df['MLTV'].fillna(df['MLTV'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['Width'].mean()
# Out:
# 70.42926049411918

# %%
df['Width']=df['Width'].fillna(df['Width'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['Tendency'].mean()
# Out:
# 0.3163714038702473

# %%
df['Tendency']=df['Tendency'].fillna(df['Tendency'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df['NSP'].mean()
# Out:
# 1.304507175110962

# %%
df['NSP']=df['NSP'].fillna(df['NSP'].mean())
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df
# Out:
#                   AC        FM        UC        DL   DS   DP  ASTV  MSTV  \
# LB
# 120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5
# 132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1
# 133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1
# 134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4
# 131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4
# ...              ...       ...       ...       ...  ...  ...   ...   ...
# 140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2
# 140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4
# 140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4
# 140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4
# 142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4
#
#                  ALTV  MLTV  Width  Tendency       NSP
# LB
# ...

# %%
df.isnull().sum()
# Out:
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2126 entries, 120.0 to 142.0
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AC        2126 non-null   float64
#  1   FM        2126 non-null   float64
#  2   UC        2126 non-null   float64
#  3   DL        2126 non-null   float64
#  4   DS        2126 non-null   float64
#  5   DP        2126 non-null   float64
#  6   ASTV      2126 non-null   float64
#  7   MSTV      2126 non-null   float64
#  8   ALTV      2126 non-null   float64
#  9   MLTV      2126 non-null   float64
#  10  Width     2126 non-null   float64
#  11  Tendency  2126 non-null   float64
#  12  NSP       2126 non-null   float64
# dtypes: float64(13)
# memory usage: 232.5 KB

# %%
df.describe()
# Out:
#                 AC           FM           UC           DL           DS  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.003219     0.009894     0.004391     0.001895     0.000003
# std       0.004370     0.067540     0.003340     0.003343     0.000141
# min      -0.019284    -0.480634    -0.014925    -0.015393    -0.001353
# 25%       0.000000     0.000000     0.001851     0.000000     0.000000
# 50%       0.001668     0.000000     0.004484     0.000000     0.000000
# 75%       0.005606     0.002567     0.006536     0.003289     0.000000
# max       0.038567     0.961268     0.030002     0.030769     0.002706
#
#                 DP         ASTV         MSTV         ALTV         MLTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000175    46.995984     1.364378    10.285964     8.284887
# std       0.000836    18.813973     1.173632    21.205041     7.734356
# ...

# %%
df[df.duplicated]
# Out:
#              AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB
# 122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1   39.0
# 148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6   35.0
#
#        Tendency  NSP
# LB
# 122.0       0.0  1.0
# 148.0       0.0  1.0

# %% [markdown]
# # Droping Duplicates

# %%
df1=df.drop_duplicates(ignore_index=True)
df1
# Out:
#             AC        FM        UC        DL   DS   DP  ASTV  MSTV       ALTV  \
# 0     0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0   0.5  43.000000
# 1     0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0   2.1   0.000000
# 2     0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0   2.1   0.000000
# 3     0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0   2.4   0.000000
# 4     0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0   2.4   0.000000
# ...        ...       ...       ...       ...  ...  ...   ...   ...        ...
# 2119  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0   0.2  25.000000
# 2120  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0   0.4  22.000000
# 2121  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0   0.4  20.000000
# 2122  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0   0.4  27.000000
# 2123  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0   0.4  35.857183
#
# ...

# %%
df1[df1.duplicated]
# Out:
# Empty DataFrame
# Columns: [AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %% [markdown]
# # outliers checking

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))
sns.boxenplot(df1)
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualiztion

# %%
# Boxplot
for i in df1:
    plt.boxplot(df1[i])
    plt.title(i)
    plt.show()

# %%
#Histogram

# %%
for i in df1:
    sns.histplot(df1[i], kde = True,
                line_kws = {'linestyle':'dashed',
                         'linewidth':'2'}).lines[0].set_color('red')
    plt.title(i)
    plt.show()

# %%
A = []
B = []

for i in df1.columns:
    mean_1 = np.mean(df1[i])
    if mean_1 > 5:
        A.append(i)
        B.append(mean_1)
plt.pie(B,labels=A,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2ac7ced0b10>,
# ...
#  [Text(0.5130293485103337, 0.9730369404945851, 'ASTV'),
#   Text(-0.8177311649160977, 0.7357416271524684, 'ALTV'),
#   Text(-1.0496553477216821, 0.32897363268091095, 'MLTV'),
#   Text(-0.06184404227819432, -1.0982601305859616, 'Width')],
#  [Text(0.2798341900965456, 0.5307474220879554, '35%'),
#   Text(-0.446035180863326, 0.40131361481043726, '8%'),
#   Text(-0.5725392805754629, 0.17944016328049686, '6%'),
#   Text(-0.03373311396992417, -0.5990509803196153, '52%')])

# %%
# Heat Map
sns.heatmap(data=df1)
# Out:
# <Axes: >

# %%
# Correlation
df1.corr()
# Out:
#                 AC        FM        UC        DL        DS        DP  \
# AC        1.000000  0.009407  0.071551 -0.093330 -0.033109 -0.083331
# FM        0.009407  1.000000 -0.053386  0.009641  0.029896  0.121249
# UC        0.071551 -0.053386  1.000000  0.189737 -0.006942  0.070348
# DL       -0.093330  0.009641  0.189737  1.000000  0.058429  0.144853
# DS       -0.033109  0.029896 -0.006942  0.058429  1.000000  0.004282
# DP       -0.083331  0.121249  0.070348  0.144853  0.004282  1.000000
# ASTV     -0.231059 -0.032838 -0.182379 -0.069907  0.008414  0.037955
# MSTV      0.133903  0.017061  0.189685  0.410216  0.016079  0.119269
# ALTV     -0.271203 -0.012005 -0.227881 -0.187275 -0.004400 -0.077760
# MLTV     -0.104655 -0.006157 -0.048754 -0.164941  0.034366 -0.113993
# Width     0.234718  0.097125  0.106550  0.408426  0.040831  0.175240
# Tendency  0.031894 -0.018408 -0.066950 -0.023759 -0.015408 -0.130510
# NSP      -0.312191  0.073991 -0.185542  0.025095  0.065399  0.294416
#
# ...

# %%
#pairplot
sns.pairplot(df1)
# Out:
# C:\Users\Navya Sri Palakuru\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [raw]
# Conclusion:
#     When we load the dataset, we find the null values and null values is filled with it's respective mean. Afetr that we identified the outliers and removed the nan values and duplicates in the data .
#     Then we use some types of visualizations and display the data like BarGraph,Heatmap and piechart. Finally data is cleaned .
